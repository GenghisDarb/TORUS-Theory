# %% [markdown]
# # Stack Timing Analysis

# %%
import pandas as pd, matplotlib.pyplot as plt
import statistics
deltas=pd.read_csv('timing.csv')['delta_ns']
plt.hist(deltas, bins=100); plt.title('Return-time deltas'); plt.show()
